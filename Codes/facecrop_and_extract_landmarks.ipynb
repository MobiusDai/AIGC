# %%
import webdataset as wds
from PIL import Image
import io

# %%
# !ls ../
# Out:
# Codes     VQVAE.md  imgs      imgs.tar  readme.md

# %%
dataset = wds.WebDataset('../imgs.tar')

# %%
for sample in dataset:
    print(sample.keys())
# Out:
# dict_keys(['__key__', '__url__', '_.ds_store', 'ds_store', '_vqvae.png'])
# dict_keys(['__key__', '__url__', 'png'])

# %%
# read the image
img = sample['png']

img = Image.open(io.BytesIO(img))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1113x377 at 0x127B2F850>

# %%
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1113x377 at 0x127B2FC40>
